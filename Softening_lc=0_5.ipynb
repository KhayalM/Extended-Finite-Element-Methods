# %% [markdown]
# <a href="https://colab.research.google.com/github/KhayalM/Extended-Finite-Element-Methods/blob/main/Softening_lc%3D0_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Mesh creation and loading

# %%
for name in dir():
    if not name.startswith('_'):
        del globals()[name]

# You can also use a magic command for a clean restart (clears all variables and re-runs cells above)
# %reset -f

print("All user-defined variables deleted.")
# Out:
# All user-defined variables deleted.

# %%
try:
    import google.colab  # noqa: F401
except ImportError:
    import gmsh
else:
    try:
        import gmsh
    except ImportError:
        # !wget "https://fem-on-colab.github.io/releases/gmsh-install.sh" -O "/tmp/gmsh-install.sh" && bash "/tmp/gmsh-install.sh"
        import gmsh
# Out:
# --2025-12-16 23:20:45--  https://fem-on-colab.github.io/releases/gmsh-install.sh
# Resolving fem-on-colab.github.io (fem-on-colab.github.io)... 185.199.109.153, 185.199.110.153, 185.199.108.153, ...
# Connecting to fem-on-colab.github.io (fem-on-colab.github.io)|185.199.109.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3497 (3.4K) [application/x-sh]
# Saving to: ‘/tmp/gmsh-install.sh’
#
# /tmp/gmsh-install.s 100%[===================>]   3.42K  --.-KB/s    in 0s
#
# 2025-12-16 23:20:45 (38.1 MB/s) - ‘/tmp/gmsh-install.sh’ saved [3497/3497]
#
# + INSTALL_PREFIX=/usr/local
# ++ echo /usr/local
# ++ awk -F/ '{print NF-1}'
# + INSTALL_PREFIX_DEPTH=2
# + PROJECT_NAME=fem-on-colab
# + SHARE_PREFIX=/usr/local/share/fem-on-colab
# + GMSH_INSTALLED=/usr/local/share/fem-on-colab/gmsh.installed
# + [[ ! -f /usr/local/share/fem-on-colab/gmsh.installed ]]
# + H5PY_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/82a9dfcc/releases/h5py-install.sh
# + [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/82a9dfcc/releases/h5py-install.sh == http* ]]
# + H5PY_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/82a9dfcc/releases/h5py-install.sh
# + H5PY_INSTALL_SCRIPT_PATH=/tmp/h5py-install.sh
# + [[ ! -f /tmp/h5py-install.sh ]]
# + wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/82a9dfcc/releases/h5py-install.sh -O /tmp/h5py-install.sh
# --2025-12-16 23:20:46--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/82a9dfcc/releases/h5py-install.sh
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/82a9dfcc53c4abb67bd2fecc9a4e3100723d61a1/releases/h5py-install.sh [following]
# --2025-12-16 23:20:46--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/82a9dfcc53c4abb67bd2fecc9a4e3100723d61a1/releases/h5py-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1724 (1.7K) [text/plain]
# Saving to: ‘/tmp/h5py-install.sh’
#
# /tmp/h5py-install.s 100%[===================>]   1.68K  --.-KB/s    in 0s
#
# 2025-12-16 23:20:46 (11.9 MB/s) - ‘/tmp/h5py-install.sh’ saved [1724/1724]
#
# + source /tmp/h5py-install.sh
# ++ set -e
# ++ set -x
# ++ INSTALL_PREFIX=/usr/local
# +++ echo /usr/local
# +++ awk -F/ '{print NF-1}'
# ++ INSTALL_PREFIX_DEPTH=2
# ++ PROJECT_NAME=fem-on-colab
# ++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++ H5PY_INSTALLED=/usr/local/share/fem-on-colab/h5py.installed
# ++ [[ ! -f /usr/local/share/fem-on-colab/h5py.installed ]]
# ++ MPI4PY_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/7a1e7fa8/releases/mpi4py-install.sh
# ++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/7a1e7fa8/releases/mpi4py-install.sh == http* ]]
# ++ MPI4PY_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/7a1e7fa8/releases/mpi4py-install.sh
# ++ MPI4PY_INSTALL_SCRIPT_PATH=/tmp/mpi4py-install.sh
# ++ [[ ! -f /tmp/mpi4py-install.sh ]]
# ++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/7a1e7fa8/releases/mpi4py-install.sh -O /tmp/mpi4py-install.sh
# --2025-12-16 23:20:46--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/7a1e7fa8/releases/mpi4py-install.sh
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/7a1e7fa825a7a0ca7ad0541d6abc466153eb8d15/releases/mpi4py-install.sh [following]
# --2025-12-16 23:20:46--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/7a1e7fa825a7a0ca7ad0541d6abc466153eb8d15/releases/mpi4py-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2583 (2.5K) [text/plain]
# Saving to: ‘/tmp/mpi4py-install.sh’
#
# /tmp/mpi4py-install 100%[===================>]   2.52K  --.-KB/s    in 0s
#
# 2025-12-16 23:20:47 (18.2 MB/s) - ‘/tmp/mpi4py-install.sh’ saved [2583/2583]
#
# ++ source /tmp/mpi4py-install.sh
# +++ set -e
# +++ set -x
# +++ INSTALL_PREFIX=/usr/local
# ++++ echo /usr/local
# ++++ awk -F/ '{print NF-1}'
# +++ INSTALL_PREFIX_DEPTH=2
# +++ PROJECT_NAME=fem-on-colab
# +++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# +++ MPI4PY_INSTALLED=/usr/local/share/fem-on-colab/mpi4py.installed
# +++ [[ ! -f /usr/local/share/fem-on-colab/mpi4py.installed ]]
# +++ GCC_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/5bc9e949/releases/gcc-install.sh
# +++ [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/5bc9e949/releases/gcc-install.sh == http* ]]
# +++ GCC_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/5bc9e949/releases/gcc-install.sh
# +++ GCC_INSTALL_SCRIPT_PATH=/tmp/gcc-install.sh
# +++ [[ ! -f /tmp/gcc-install.sh ]]
# +++ wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/5bc9e949/releases/gcc-install.sh -O /tmp/gcc-install.sh
# --2025-12-16 23:20:47--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/5bc9e949/releases/gcc-install.sh
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/5bc9e949c120f6479a4c44f2258c422517cb87aa/releases/gcc-install.sh [following]
# --2025-12-16 23:20:47--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/5bc9e949c120f6479a4c44f2258c422517cb87aa/releases/gcc-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8358 (8.2K) [text/plain]
# Saving to: ‘/tmp/gcc-install.sh’
#
# /tmp/gcc-install.sh 100%[===================>]   8.16K  --.-KB/s    in 0s
#
# 2025-12-16 23:20:47 (56.2 MB/s) - ‘/tmp/gcc-install.sh’ saved [8358/8358]
#
# +++ source /tmp/gcc-install.sh
# ++++ set -e
# ++++ set -x
# ++++ INSTALL_PREFIX=/usr/local
# +++++ echo /usr/local
# +++++ awk -F/ '{print NF-1}'
# ++++ INSTALL_PREFIX_DEPTH=2
# ++++ PROJECT_NAME=fem-on-colab
# ++++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++++ GCC_INSTALLED=/usr/local/share/fem-on-colab/gcc.installed
# ++++ [[ ! -L /usr/local/lib64 ]]
# ++++ [[ -e /usr/local/lib64 ]]
# ++++ ln -s /usr/local/lib /usr/local/lib64
# ++++ [[ ! -L /usr/local/lib64 ]]
# ++++ [[ ! -d /usr/local/lib64 ]]
# ++++ [[ ! -f /usr/local/share/fem-on-colab/gcc.installed ]]
# ++++ GCC_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20251107-062633-3ce8afd/gcc-install.tar.gz
# ++++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20251107-062633-3ce8afd/gcc-install.tar.gz == http* ]]
# ++++ GCC_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20251107-062633-3ce8afd/gcc-install.tar.gz
# ++++ GCC_ARCHIVE_PATH=/tmp/gcc-install.tar.gz
# ++++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20251107-062633-3ce8afd/gcc-install.tar.gz -O /tmp/gcc-install.tar.gz
# --2025-12-16 23:20:47--  https://github.com/fem-on-colab/fem-on-colab/releases/download/gcc-20251107-062633-3ce8afd/gcc-install.tar.gz
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/b087775b-c4e3-4a2e-83a7-5b7370214f4b?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-17T00%3A20%3A09Z&rscd=attachment%3B+filename%3Dgcc-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-16T23%3A19%3A21Z&ske=2025-12-17T00%3A20%3A09Z&sks=b&skv=2018-11-09&sig=WJschB%2BoiBcLArIUJ0Inub%2B4nqYsxXYTu8OdYIQowLk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NTkzMDg0NywibmJmIjoxNzY1OTI3MjQ3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.ZF184JuUt2jvSfehLbhUrJ8gvvshWt_4lZD8VdeYk_c&response-content-disposition=attachment%3B%20filename%3Dgcc-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-12-16 23:20:47--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/b087775b-c4e3-4a2e-83a7-5b7370214f4b?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-17T00%3A20%3A09Z&rscd=attachment%3B+filename%3Dgcc-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-16T23%3A19%3A21Z&ske=2025-12-17T00%3A20%3A09Z&sks=b&skv=2018-11-09&sig=WJschB%2BoiBcLArIUJ0Inub%2B4nqYsxXYTu8OdYIQowLk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NTkzMDg0NywibmJmIjoxNzY1OTI3MjQ3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.ZF184JuUt2jvSfehLbhUrJ8gvvshWt_4lZD8VdeYk_c&response-content-disposition=attachment%3B%20filename%3Dgcc-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 688030755 (656M) [application/octet-stream]
# Saving to: ‘/tmp/gcc-install.tar.gz’
#
# /tmp/gcc-install.ta 100%[===================>] 656.16M   104MB/s    in 6.7s
#
# 2025-12-16 23:20:54 (97.7 MB/s) - ‘/tmp/gcc-install.tar.gz’ saved [688030755/688030755]
#
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# ++++ tar -xzf /tmp/gcc-install.tar.gz --strip-components=2 --directory=/usr/local
# ++++ apt install -y -qq zlib1g-dev
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# ++++ for LEGACY_GPP in /usr/bin/g++-*
# +++++ /usr/bin/g++-11 -dumpversion
# ++++ LEGACY_GCC_VERSION=11
# ++++ update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-11 11
# update-alternatives: using /usr/bin/g++-11 to provide /usr/bin/g++ (g++) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-11 11
# update-alternatives: using /usr/bin/gcc-11 to provide /usr/bin/gcc (gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ar gcc-ar /usr/bin/gcc-ar-11 11
# update-alternatives: using /usr/bin/gcc-ar-11 to provide /usr/bin/gcc-ar (gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-nm gcc-nm /usr/bin/gcc-nm-11 11
# update-alternatives: using /usr/bin/gcc-nm-11 to provide /usr/bin/gcc-nm (gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ranlib gcc-ranlib /usr/bin/gcc-ranlib-11 11
# update-alternatives: using /usr/bin/gcc-ranlib-11 to provide /usr/bin/gcc-ranlib (gcc-ranlib) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-g++ x86_64-linux-gnu-g++ /usr/bin/x86_64-linux-gnu-g++-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-g++-11 to provide /usr/bin/x86_64-linux-gnu-g++ (x86_64-linux-gnu-g++) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc x86_64-linux-gnu-gcc /usr/bin/x86_64-linux-gnu-gcc-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-11 to provide /usr/bin/x86_64-linux-gnu-gcc (x86_64-linux-gnu-gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ar x86_64-linux-gnu-gcc-ar /usr/bin/x86_64-linux-gnu-gcc-ar-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-ar-11 to provide /usr/bin/x86_64-linux-gnu-gcc-ar (x86_64-linux-gnu-gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-nm x86_64-linux-gnu-gcc-nm /usr/bin/x86_64-linux-gnu-gcc-nm-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-nm-11 to provide /usr/bin/x86_64-linux-gnu-gcc-nm (x86_64-linux-gnu-gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ranlib x86_64-linux-gnu-gcc-ranlib /usr/bin/x86_64-linux-gnu-gcc-ranlib-11 11
# update-alternatives: using /usr/bin/x86_64-linux-gnu-gcc-ranlib-11 to provide /usr/bin/x86_64-linux-gnu-gcc-ranlib (x86_64-linux-gnu-gcc-ranlib) in auto mode
# +++++ /usr/local/bin/g++ -dumpversion
# ++++ GCC_VERSION=12
# ++++ update-alternatives --install /usr/bin/g++ g++ /usr/local/bin/g++-12 12
# update-alternatives: using /usr/local/bin/g++-12 to provide /usr/bin/g++ (g++) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc gcc /usr/local/bin/gcc-12 12
# update-alternatives: using /usr/local/bin/gcc-12 to provide /usr/bin/gcc (gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ar gcc-ar /usr/local/bin/gcc-ar-12 12
# update-alternatives: using /usr/local/bin/gcc-ar-12 to provide /usr/bin/gcc-ar (gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-nm gcc-nm /usr/local/bin/gcc-nm-12 12
# update-alternatives: using /usr/local/bin/gcc-nm-12 to provide /usr/bin/gcc-nm (gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/gcc-ranlib gcc-ranlib /usr/local/bin/gcc-ranlib-12 12
# update-alternatives: using /usr/local/bin/gcc-ranlib-12 to provide /usr/bin/gcc-ranlib (gcc-ranlib) in auto mode
# ++++ update-alternatives --install /usr/bin/gfortran gfortran /usr/local/bin/gfortran-12 12
# update-alternatives: using /usr/local/bin/gfortran-12 to provide /usr/bin/gfortran (gfortran) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-g++ x86_64-linux-gnu-g++ /usr/local/bin/x86_64-linux-gnu-g++-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-g++-12 to provide /usr/bin/x86_64-linux-gnu-g++ (x86_64-linux-gnu-g++) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc x86_64-linux-gnu-gcc /usr/local/bin/x86_64-linux-gnu-gcc-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-12 to provide /usr/bin/x86_64-linux-gnu-gcc (x86_64-linux-gnu-gcc) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ar x86_64-linux-gnu-gcc-ar /usr/local/bin/x86_64-linux-gnu-gcc-ar-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-ar-12 to provide /usr/bin/x86_64-linux-gnu-gcc-ar (x86_64-linux-gnu-gcc-ar) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-nm x86_64-linux-gnu-gcc-nm /usr/local/bin/x86_64-linux-gnu-gcc-nm-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-nm-12 to provide /usr/bin/x86_64-linux-gnu-gcc-nm (x86_64-linux-gnu-gcc-nm) in auto mode
# ++++ update-alternatives --install /usr/bin/x86_64-linux-gnu-gcc-ranlib x86_64-linux-gnu-gcc-ranlib /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12 12
# update-alternatives: using /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12 to provide /usr/bin/x86_64-linux-gnu-gcc-ranlib (x86_64-linux-gnu-gcc-ranlib) in auto mode
# ++++ update-alternatives --set g++ /usr/local/bin/g++-12
# ++++ update-alternatives --set gcc /usr/local/bin/gcc-12
# ++++ update-alternatives --set gcc-ar /usr/local/bin/gcc-ar-12
# ++++ update-alternatives --set gcc-nm /usr/local/bin/gcc-nm-12
# ++++ update-alternatives --set gcc-ranlib /usr/local/bin/gcc-ranlib-12
# ++++ update-alternatives --set gfortran /usr/local/bin/gfortran-12
# ++++ update-alternatives --set x86_64-linux-gnu-g++ /usr/local/bin/x86_64-linux-gnu-g++-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc /usr/local/bin/x86_64-linux-gnu-gcc-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-ar /usr/local/bin/x86_64-linux-gnu-gcc-ar-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-nm /usr/local/bin/x86_64-linux-gnu-gcc-nm-12
# ++++ update-alternatives --set x86_64-linux-gnu-gcc-ranlib /usr/local/bin/x86_64-linux-gnu-gcc-ranlib-12
# ++++ [[ /tmp/gcc-install.tar.gz != skip ]]
# +++++ which python3
# ++++ PYTHON_EXEC=/usr/bin/python3
# +++++ dirname /usr/bin/python3
# ++++ PYTHON_EXEC_DIR=/usr/bin
# +++++ objdump -x /usr/bin/python3
# +++++ sed 's| ||g'
# +++++ grep 'R.*PATH'
# +++++ sed 's|R.*PATH||g'
# +++++ sed 's|$ORIGIN|/usr/bin|g'
# ++++ PYTHON_RPATH=
# ++++ [[ -z '' ]]
# ++++ PYTHON_RPATH=/usr/lib/x86_64-linux-gnu
# ++++ INSTALL_PREFIX_RPATH=/usr/local/lib
# ++++ [[ -L /usr/lib/x86_64-linux-gnu/libstdc++.so ]]
# +++++ basename /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30
# ++++ LIBSTDCXX_SYSTEM_VERSION=libstdc++.so.6.0.30
# +++++ basename /usr/local/lib/libstdc++.so.6.0.30 /usr/local/lib/libstdc++.so.6.0.30-gdb.py
# ++++ LIBSTDCXX_INSTALL_PREFIX_VERSION=libstdc++.so.6.0.30
# ++++ [[ libstdc++.so.6.0.30 != \l\i\b\s\t\d\c\+\+\.\s\o\.\6\.\0\.\3\0 ]]
# ++++ mkdir -p /usr/local/share/fem-on-colab
# ++++ touch /usr/local/share/fem-on-colab/gcc.installed
# +++ MPI4PY_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20251107-064919-3ce8afd/mpi4py-install.tar.gz
# +++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20251107-064919-3ce8afd/mpi4py-install.tar.gz == http* ]]
# +++ MPI4PY_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20251107-064919-3ce8afd/mpi4py-install.tar.gz
# +++ MPI4PY_ARCHIVE_PATH=/tmp/mpi4py-install.tar.gz
# +++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20251107-064919-3ce8afd/mpi4py-install.tar.gz -O /tmp/mpi4py-install.tar.gz
# --2025-12-16 23:21:23--  https://github.com/fem-on-colab/fem-on-colab/releases/download/mpi4py-20251107-064919-3ce8afd/mpi4py-install.tar.gz
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/88f829fd-26e1-4c11-977d-ffbfc50846af?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-17T00%3A19%3A10Z&rscd=attachment%3B+filename%3Dmpi4py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-16T23%3A19%3A07Z&ske=2025-12-17T00%3A19%3A10Z&sks=b&skv=2018-11-09&sig=IIMYT7W2yrSNEZVCEmE2XWpLQk21OJ3BJkAtcd6AHfg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NTkyOTA4MywibmJmIjoxNzY1OTI3MjgzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.gMzwDShvTG4hqFAm0v73z_jyd1g4D0srrCkeno__KvE&response-content-disposition=attachment%3B%20filename%3Dmpi4py-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-12-16 23:21:23--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/88f829fd-26e1-4c11-977d-ffbfc50846af?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-17T00%3A19%3A10Z&rscd=attachment%3B+filename%3Dmpi4py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-16T23%3A19%3A07Z&ske=2025-12-17T00%3A19%3A10Z&sks=b&skv=2018-11-09&sig=IIMYT7W2yrSNEZVCEmE2XWpLQk21OJ3BJkAtcd6AHfg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NTkyOTA4MywibmJmIjoxNzY1OTI3MjgzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.gMzwDShvTG4hqFAm0v73z_jyd1g4D0srrCkeno__KvE&response-content-disposition=attachment%3B%20filename%3Dmpi4py-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14180426 (14M) [application/octet-stream]
# Saving to: ‘/tmp/mpi4py-install.tar.gz’
#
# /tmp/mpi4py-install 100%[===================>]  13.52M  67.7MB/s    in 0.2s
#
# 2025-12-16 23:21:24 (67.7 MB/s) - ‘/tmp/mpi4py-install.tar.gz’ saved [14180426/14180426]
#
# +++ [[ /tmp/mpi4py-install.tar.gz != skip ]]
# +++ tar -xzf /tmp/mpi4py-install.tar.gz --strip-components=2 --directory=/usr/local
# +++ [[ /tmp/mpi4py-install.tar.gz != skip ]]
# +++ command -v mpicc
# /usr/local/bin/mpicc
# +++ [[ /tmp/mpi4py-install.tar.gz != skip ]]
# +++ MPI_LIBS=('libhwloc*.so*' 'libmpi*.so*' 'libopen-pal*.so*' 'libpmix*.so*' 'libprrte*.so*')
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libhwloc*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libhwloc.so /usr/lib/x86_64-linux-gnu/libhwloc.so.15 /usr/lib/x86_64-linux-gnu/libhwloc.so.15.5.2
# +++ ln -fs /usr/local/lib/libhwloc.so /usr/local/lib/libhwloc.so.15 /usr/local/lib/libhwloc.so.15.5.3 /usr/local/lib/libhwloc.so.15.8.1 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libmpi*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libmpi_cxx.so /usr/lib/x86_64-linux-gnu/libmpi_cxx.so.40 /usr/lib/x86_64-linux-gnu/libmpi_cxx.so.40.30.1 /usr/lib/x86_64-linux-gnu/libmpi_java.so /usr/lib/x86_64-linux-gnu/libmpi_java.so.40 /usr/lib/x86_64-linux-gnu/libmpi_java.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_mpifh-gfortran.so /usr/lib/x86_64-linux-gnu/libmpi_mpifh-gfortran.so.40 /usr/lib/x86_64-linux-gnu/libmpi_mpifh-gfortran.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_mpifh.so /usr/lib/x86_64-linux-gnu/libmpi_mpifh.so.40 /usr/lib/x86_64-linux-gnu/libmpi_mpifh.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpiseq_seq-5.4.0.so /usr/lib/x86_64-linux-gnu/libmpiseq_seq-5.4.so /usr/lib/x86_64-linux-gnu/libmpiseq_seq.so /usr/lib/x86_64-linux-gnu/libmpi++.so /usr/lib/x86_64-linux-gnu/libmpi.so /usr/lib/x86_64-linux-gnu/libmpi.so.40 /usr/lib/x86_64-linux-gnu/libmpi.so.40.30.2 /usr/lib/x86_64-linux-gnu/libmpi_usempif08-gfortran.so /usr/lib/x86_64-linux-gnu/libmpi_usempif08-gfortran.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempif08-gfortran.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_usempif08.so /usr/lib/x86_64-linux-gnu/libmpi_usempif08.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempif08.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr-gfortran.so /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr-gfortran.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr-gfortran.so.40.30.0 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr.so /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr.so.40 /usr/lib/x86_64-linux-gnu/libmpi_usempi_ignore_tkr.so.40.30.0
# +++ ln -fs /usr/local/lib/libmpi_mpifh.so /usr/local/lib/libmpi_mpifh.so.40 /usr/local/lib/libmpi_mpifh.so.40.40.1 /usr/local/lib/libmpi.so /usr/local/lib/libmpi.so.40 /usr/local/lib/libmpi.so.40.40.7 /usr/local/lib/libmpi_usempif08.so /usr/local/lib/libmpi_usempif08.so.40 /usr/local/lib/libmpi_usempif08.so.40.40.3 /usr/local/lib/libmpi_usempi_ignore_tkr.so /usr/local/lib/libmpi_usempi_ignore_tkr.so.40 /usr/local/lib/libmpi_usempi_ignore_tkr.so.40.40.1 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libopen-pal*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libopen-pal.so /usr/lib/x86_64-linux-gnu/libopen-pal.so.40 /usr/lib/x86_64-linux-gnu/libopen-pal.so.40.30.2
# +++ ln -fs /usr/local/lib/libopen-pal.so /usr/local/lib/libopen-pal.so.80 /usr/local/lib/libopen-pal.so.80.0.5 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libpmix*.so*'
# +++ rm -f /usr/lib/x86_64-linux-gnu/libpmix.so /usr/lib/x86_64-linux-gnu/libpmix.so.2 /usr/lib/x86_64-linux-gnu/libpmix.so.2.5.2
# +++ ln -fs /usr/local/lib/libpmix.so /usr/local/lib/libpmix.so.2 /usr/local/lib/libpmix.so.2.13.9 /usr/lib
# +++ for MPI_LIB in "${MPI_LIBS[@]}"
# +++ rm -f '/usr/lib/libprrte*.so*'
# +++ rm -f '/usr/lib/x86_64-linux-gnu/libprrte*.so*'
# +++ ln -fs /usr/local/lib/libprrte.so /usr/local/lib/libprrte.so.3 /usr/local/lib/libprrte.so.3.0.12 /usr/lib
# +++ mkdir -p /usr/local/share/fem-on-colab
# +++ touch /usr/local/share/fem-on-colab/mpi4py.installed
# ++ H5PY_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20251107-070632-3ce8afd/h5py-install.tar.gz
# ++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20251107-070632-3ce8afd/h5py-install.tar.gz == http* ]]
# ++ H5PY_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20251107-070632-3ce8afd/h5py-install.tar.gz
# ++ H5PY_ARCHIVE_PATH=/tmp/h5py-install.tar.gz
# ++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20251107-070632-3ce8afd/h5py-install.tar.gz -O /tmp/h5py-install.tar.gz
# --2025-12-16 23:21:24--  https://github.com/fem-on-colab/fem-on-colab/releases/download/h5py-20251107-070632-3ce8afd/h5py-install.tar.gz
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/c9559fc4-3e0a-4e0d-bf79-2e5dcad79c56?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-17T00%3A19%3A53Z&rscd=attachment%3B+filename%3Dh5py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-16T23%3A18%3A55Z&ske=2025-12-17T00%3A19%3A53Z&sks=b&skv=2018-11-09&sig=9OPoFZ5HihBsO4zL8KMGCzSWBLbv%2F4Qx6KonCmzZvXs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NTkyOTA4NCwibmJmIjoxNzY1OTI3Mjg0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.iMOHy9oBJbWpsbcvCl5ILcMyVingKTGViS91Lc-LQD4&response-content-disposition=attachment%3B%20filename%3Dh5py-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-12-16 23:21:24--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/c9559fc4-3e0a-4e0d-bf79-2e5dcad79c56?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-17T00%3A19%3A53Z&rscd=attachment%3B+filename%3Dh5py-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-16T23%3A18%3A55Z&ske=2025-12-17T00%3A19%3A53Z&sks=b&skv=2018-11-09&sig=9OPoFZ5HihBsO4zL8KMGCzSWBLbv%2F4Qx6KonCmzZvXs%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NTkyOTA4NCwibmJmIjoxNzY1OTI3Mjg0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.iMOHy9oBJbWpsbcvCl5ILcMyVingKTGViS91Lc-LQD4&response-content-disposition=attachment%3B%20filename%3Dh5py-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14970080 (14M) [application/octet-stream]
# Saving to: ‘/tmp/h5py-install.tar.gz’
#
# /tmp/h5py-install.t 100%[===================>]  14.28M  63.5MB/s    in 0.2s
#
# 2025-12-16 23:21:25 (63.5 MB/s) - ‘/tmp/h5py-install.tar.gz’ saved [14970080/14970080]
#
# ++ [[ /tmp/h5py-install.tar.gz != skip ]]
# ++ rm -rf '/usr/lib/python*/*-packages/h5py*'
# ++ rm -rf /usr/local/lib/python3.12/dist-packages/h5py /usr/local/lib/python3.12/dist-packages/h5py-3.15.1.dist-info /usr/local/lib/python3.12/dist-packages/h5py.libs
# ++ tar -xzf /tmp/h5py-install.tar.gz --strip-components=2 --directory=/usr/local
# ++ mkdir -p /usr/local/share/fem-on-colab
# ++ touch /usr/local/share/fem-on-colab/h5py.installed
# + OCC_INSTALL_SCRIPT_PATH=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/69261fbd/releases/occ-install.sh
# + [[ https://github.com/fem-on-colab/fem-on-colab.github.io/raw/69261fbd/releases/occ-install.sh == http* ]]
# + OCC_INSTALL_SCRIPT_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab.github.io/raw/69261fbd/releases/occ-install.sh
# + OCC_INSTALL_SCRIPT_PATH=/tmp/occ-install.sh
# + [[ ! -f /tmp/occ-install.sh ]]
# + wget https://github.com/fem-on-colab/fem-on-colab.github.io/raw/69261fbd/releases/occ-install.sh -O /tmp/occ-install.sh
# --2025-12-16 23:21:25--  https://github.com/fem-on-colab/fem-on-colab.github.io/raw/69261fbd/releases/occ-install.sh
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/69261fbdbceb0284bb88abbf1880e587faaba769/releases/occ-install.sh [following]
# --2025-12-16 23:21:26--  https://raw.githubusercontent.com/fem-on-colab/fem-on-colab.github.io/69261fbdbceb0284bb88abbf1880e587faaba769/releases/occ-install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1885 (1.8K) [text/plain]
# Saving to: ‘/tmp/occ-install.sh’
#
# /tmp/occ-install.sh 100%[===================>]   1.84K  --.-KB/s    in 0s
#
# 2025-12-16 23:21:26 (25.8 MB/s) - ‘/tmp/occ-install.sh’ saved [1885/1885]
#
# + source /tmp/occ-install.sh
# ++ set -e
# ++ set -x
# ++ INSTALL_PREFIX=/usr/local
# +++ echo /usr/local
# +++ awk -F/ '{print NF-1}'
# ++ INSTALL_PREFIX_DEPTH=2
# ++ PROJECT_NAME=fem-on-colab
# ++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# ++ OCC_INSTALLED=/usr/local/share/fem-on-colab/occ.installed
# ++ [[ ! -f /usr/local/share/fem-on-colab/occ.installed ]]
# ++ GCC_INSTALL_SCRIPT_PATH=/tmp/gcc-install.sh
# ++ [[ /tmp/gcc-install.sh == http* ]]
# ++ source /tmp/gcc-install.sh
# +++ set -e
# +++ set -x
# +++ INSTALL_PREFIX=/usr/local
# ++++ echo /usr/local
# ++++ awk -F/ '{print NF-1}'
# +++ INSTALL_PREFIX_DEPTH=2
# +++ PROJECT_NAME=fem-on-colab
# +++ SHARE_PREFIX=/usr/local/share/fem-on-colab
# +++ GCC_INSTALLED=/usr/local/share/fem-on-colab/gcc.installed
# +++ [[ ! -L /usr/local/lib64 ]]
# +++ [[ ! -L /usr/local/lib64 ]]
# +++ [[ ! -d /usr/local/lib64 ]]
# +++ [[ ! -f /usr/local/share/fem-on-colab/gcc.installed ]]
# ++ OCC_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/occ-20251107-064917-3ce8afd/occ-install.tar.gz
# ++ [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/occ-20251107-064917-3ce8afd/occ-install.tar.gz == http* ]]
# ++ OCC_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/occ-20251107-064917-3ce8afd/occ-install.tar.gz
# ++ OCC_ARCHIVE_PATH=/tmp/occ-install.tar.gz
# ++ wget https://github.com/fem-on-colab/fem-on-colab/releases/download/occ-20251107-064917-3ce8afd/occ-install.tar.gz -O /tmp/occ-install.tar.gz
# --2025-12-16 23:21:26--  https://github.com/fem-on-colab/fem-on-colab/releases/download/occ-20251107-064917-3ce8afd/occ-install.tar.gz
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/e6364285-1df5-4fd8-8596-a8bf119a645d?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-17T00%3A20%3A11Z&rscd=attachment%3B+filename%3Docc-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-16T23%3A19%3A38Z&ske=2025-12-17T00%3A20%3A11Z&sks=b&skv=2018-11-09&sig=g03TbK6NM0d5hACAyqOFNckv3yZJeuDpAd4hqGctfvU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NTkyOTA4NiwibmJmIjoxNzY1OTI3Mjg2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.sPA8hgYnjT1AigQww9kJOFqkrGc8nyAKaxXrhi9NhMI&response-content-disposition=attachment%3B%20filename%3Docc-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-12-16 23:21:26--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/e6364285-1df5-4fd8-8596-a8bf119a645d?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-17T00%3A20%3A11Z&rscd=attachment%3B+filename%3Docc-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-16T23%3A19%3A38Z&ske=2025-12-17T00%3A20%3A11Z&sks=b&skv=2018-11-09&sig=g03TbK6NM0d5hACAyqOFNckv3yZJeuDpAd4hqGctfvU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NTkyOTA4NiwibmJmIjoxNzY1OTI3Mjg2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.sPA8hgYnjT1AigQww9kJOFqkrGc8nyAKaxXrhi9NhMI&response-content-disposition=attachment%3B%20filename%3Docc-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32188795 (31M) [application/octet-stream]
# Saving to: ‘/tmp/occ-install.tar.gz’
#
# /tmp/occ-install.ta 100%[===================>]  30.70M  68.8MB/s    in 0.4s
#
# 2025-12-16 23:21:27 (68.8 MB/s) - ‘/tmp/occ-install.tar.gz’ saved [32188795/32188795]
#
# ++ [[ /tmp/occ-install.tar.gz != skip ]]
# ++ tar -xzf /tmp/occ-install.tar.gz --strip-components=2 --directory=/usr/local
# ++ [[ /tmp/occ-install.tar.gz != skip ]]
# ++ ln -fs /usr/local/lib/libTKBinL.so /usr/local/lib/libTKBinL.so.8.0 /usr/local/lib/libTKBinL.so.8.0.0 /usr/local/lib/libTKBin.so /usr/local/lib/libTKBin.so.8.0 /usr/local/lib/libTKBin.so.8.0.0 /usr/local/lib/libTKBinTObj.so /usr/local/lib/libTKBinTObj.so.8.0 /usr/local/lib/libTKBinTObj.so.8.0.0 /usr/local/lib/libTKBinXCAF.so /usr/local/lib/libTKBinXCAF.so.8.0 /usr/local/lib/libTKBinXCAF.so.8.0.0 /usr/local/lib/libTKBool.so /usr/local/lib/libTKBool.so.8.0 /usr/local/lib/libTKBool.so.8.0.0 /usr/local/lib/libTKBO.so /usr/local/lib/libTKBO.so.8.0 /usr/local/lib/libTKBO.so.8.0.0 /usr/local/lib/libTKBRep.so /usr/local/lib/libTKBRep.so.8.0 /usr/local/lib/libTKBRep.so.8.0.0 /usr/local/lib/libTKCAF.so /usr/local/lib/libTKCAF.so.8.0 /usr/local/lib/libTKCAF.so.8.0.0 /usr/local/lib/libTKCDF.so /usr/local/lib/libTKCDF.so.8.0 /usr/local/lib/libTKCDF.so.8.0.0 /usr/local/lib/libTKDECascade.so /usr/local/lib/libTKDECascade.so.8.0 /usr/local/lib/libTKDECascade.so.8.0.0 /usr/local/lib/libTKDEIGES.so /usr/local/lib/libTKDEIGES.so.8.0 /usr/local/lib/libTKDEIGES.so.8.0.0 /usr/local/lib/libTKDEOBJ.so /usr/local/lib/libTKDEOBJ.so.8.0 /usr/local/lib/libTKDEOBJ.so.8.0.0 /usr/local/lib/libTKDEPLY.so /usr/local/lib/libTKDEPLY.so.8.0 /usr/local/lib/libTKDEPLY.so.8.0.0 /usr/local/lib/libTKDE.so /usr/local/lib/libTKDE.so.8.0 /usr/local/lib/libTKDE.so.8.0.0 /usr/local/lib/libTKDESTEP.so /usr/local/lib/libTKDESTEP.so.8.0 /usr/local/lib/libTKDESTEP.so.8.0.0 /usr/local/lib/libTKDESTL.so /usr/local/lib/libTKDESTL.so.8.0 /usr/local/lib/libTKDESTL.so.8.0.0 /usr/local/lib/libTKDEVRML.so /usr/local/lib/libTKDEVRML.so.8.0 /usr/local/lib/libTKDEVRML.so.8.0.0 /usr/local/lib/libTKernel.so /usr/local/lib/libTKernel.so.8.0 /usr/local/lib/libTKernel.so.8.0.0 /usr/local/lib/libTKExpress.so /usr/local/lib/libTKExpress.so.8.0 /usr/local/lib/libTKExpress.so.8.0.0 /usr/local/lib/libTKFeat.so /usr/local/lib/libTKFeat.so.8.0 /usr/local/lib/libTKFeat.so.8.0.0 /usr/local/lib/libTKFillet.so /usr/local/lib/libTKFillet.so.8.0 /usr/local/lib/libTKFillet.so.8.0.0 /usr/local/lib/libTKG2d.so /usr/local/lib/libTKG2d.so.8.0 /usr/local/lib/libTKG2d.so.8.0.0 /usr/local/lib/libTKG3d.so /usr/local/lib/libTKG3d.so.8.0 /usr/local/lib/libTKG3d.so.8.0.0 /usr/local/lib/libTKGeomAlgo.so /usr/local/lib/libTKGeomAlgo.so.8.0 /usr/local/lib/libTKGeomAlgo.so.8.0.0 /usr/local/lib/libTKGeomBase.so /usr/local/lib/libTKGeomBase.so.8.0 /usr/local/lib/libTKGeomBase.so.8.0.0 /usr/local/lib/libTKHelix.so /usr/local/lib/libTKHelix.so.8.0 /usr/local/lib/libTKHelix.so.8.0.0 /usr/local/lib/libTKHLR.so /usr/local/lib/libTKHLR.so.8.0 /usr/local/lib/libTKHLR.so.8.0.0 /usr/local/lib/libTKLCAF.so /usr/local/lib/libTKLCAF.so.8.0 /usr/local/lib/libTKLCAF.so.8.0.0 /usr/local/lib/libTKMath.so /usr/local/lib/libTKMath.so.8.0 /usr/local/lib/libTKMath.so.8.0.0 /usr/local/lib/libTKMesh.so /usr/local/lib/libTKMesh.so.8.0 /usr/local/lib/libTKMesh.so.8.0.0 /usr/local/lib/libTKOffset.so /usr/local/lib/libTKOffset.so.8.0 /usr/local/lib/libTKOffset.so.8.0.0 /usr/local/lib/libTKPrim.so /usr/local/lib/libTKPrim.so.8.0 /usr/local/lib/libTKPrim.so.8.0.0 /usr/local/lib/libTKRWMesh.so /usr/local/lib/libTKRWMesh.so.8.0 /usr/local/lib/libTKRWMesh.so.8.0.0 /usr/local/lib/libTKService.so /usr/local/lib/libTKService.so.8.0 /usr/local/lib/libTKService.so.8.0.0 /usr/local/lib/libTKShHealing.so /usr/local/lib/libTKShHealing.so.8.0 /usr/local/lib/libTKShHealing.so.8.0.0 /usr/local/lib/libTKStdL.so /usr/local/lib/libTKStdL.so.8.0 /usr/local/lib/libTKStdL.so.8.0.0 /usr/local/lib/libTKStd.so /usr/local/lib/libTKStd.so.8.0 /usr/local/lib/libTKStd.so.8.0.0 /usr/local/lib/libTKTObj.so /usr/local/lib/libTKTObj.so.8.0 /usr/local/lib/libTKTObj.so.8.0.0 /usr/local/lib/libTKTopAlgo.so /usr/local/lib/libTKTopAlgo.so.8.0 /usr/local/lib/libTKTopAlgo.so.8.0.0 /usr/local/lib/libTKV3d.so /usr/local/lib/libTKV3d.so.8.0 /usr/local/lib/libTKV3d.so.8.0.0 /usr/local/lib/libTKVCAF.so /usr/local/lib/libTKVCAF.so.8.0 /usr/local/lib/libTKVCAF.so.8.0.0 /usr/local/lib/libTKXC ...
# ++ apt install -y -qq libfontconfig1 libgl1
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libgl1 is already the newest version (1.4.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# ++ mkdir -p /usr/local/share/fem-on-colab
# ++ touch /usr/local/share/fem-on-colab/occ.installed
# + GMSH_ARCHIVE_PATH=https://github.com/fem-on-colab/fem-on-colab/releases/download/gmsh-20251129-010226-717225a/gmsh-install.tar.gz
# + [[ https://github.com/fem-on-colab/fem-on-colab/releases/download/gmsh-20251129-010226-717225a/gmsh-install.tar.gz == http* ]]
# + GMSH_ARCHIVE_DOWNLOAD=https://github.com/fem-on-colab/fem-on-colab/releases/download/gmsh-20251129-010226-717225a/gmsh-install.tar.gz
# + GMSH_ARCHIVE_PATH=/tmp/gmsh-install.tar.gz
# + wget https://github.com/fem-on-colab/fem-on-colab/releases/download/gmsh-20251129-010226-717225a/gmsh-install.tar.gz -O /tmp/gmsh-install.tar.gz
# --2025-12-16 23:21:31--  https://github.com/fem-on-colab/fem-on-colab/releases/download/gmsh-20251129-010226-717225a/gmsh-install.tar.gz
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/370599515/76db6dc9-54ea-4098-9171-84c95c162d03?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-17T00%3A20%3A03Z&rscd=attachment%3B+filename%3Dgmsh-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-16T23%3A19%3A58Z&ske=2025-12-17T00%3A20%3A03Z&sks=b&skv=2018-11-09&sig=73xz%2BRWdWAfiJ6jzx57fzxAdOkgQGTnrSejF3BVJip0%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NTkyOTA5MiwibmJmIjoxNzY1OTI3MjkyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.lj0mj1NxPl8yJgCAhSyMeFJDZVQsqgkx3ZHdBg0GYIc&response-content-disposition=attachment%3B%20filename%3Dgmsh-install.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-12-16 23:21:32--  https://release-assets.githubusercontent.com/github-production-release-asset/370599515/76db6dc9-54ea-4098-9171-84c95c162d03?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-17T00%3A20%3A03Z&rscd=attachment%3B+filename%3Dgmsh-install.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-16T23%3A19%3A58Z&ske=2025-12-17T00%3A20%3A03Z&sks=b&skv=2018-11-09&sig=73xz%2BRWdWAfiJ6jzx57fzxAdOkgQGTnrSejF3BVJip0%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NTkyOTA5MiwibmJmIjoxNzY1OTI3MjkyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.lj0mj1NxPl8yJgCAhSyMeFJDZVQsqgkx3ZHdBg0GYIc&response-content-disposition=attachment%3B%20filename%3Dgmsh-install.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12441244 (12M) [application/octet-stream]
# Saving to: ‘/tmp/gmsh-install.tar.gz’
#
# /tmp/gmsh-install.t 100%[===================>]  11.86M  57.0MB/s    in 0.2s
#
# 2025-12-16 23:21:32 (57.0 MB/s) - ‘/tmp/gmsh-install.tar.gz’ saved [12441244/12441244]
#
# + [[ /tmp/gmsh-install.tar.gz != skip ]]
# + tar -xzf /tmp/gmsh-install.tar.gz --strip-components=2 --directory=/usr/local
# + [[ /tmp/gmsh-install.tar.gz != skip ]]
# + ln -fs /usr/local/lib/libgmsh.so /usr/local/lib/libgmsh.so.5.0 /usr/local/lib/libgmsh.so.5.0.0 /usr/lib
# + mkdir -p /usr/local/share/fem-on-colab
# + touch /usr/local/share/fem-on-colab/gmsh.installed
# + set +x
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ################################################################################
# #     This installation is offered by FEM on Colab, an open-source project     #
# #       developed and maintained at Università Cattolica del Sacro Cuore       #
# #   by Prof. Francesco Ballarin. Please see https://fem-on-colab.github.io/    #
# #       for more details, including a list of further available packages       #
# #       and how to sponsor the development or contribute to the project.       #
# #                                                                              #
# #   We are conducting an informal survey on FEM on Colab usage by our users.   #
# #   The survey is anonymous, and its compilation will typically only require   #
# #   a couple of minutes of your time. If you wish, give us your feedback at    #
# #                     https://forms.gle/36sZZWNvPpUv8XWr7                      #
# ################################################################################

# %%
import gmsh

# Initialize Gmsh
gmsh.initialize()

# Create a new model
gmsh.model.add("I_beam")

# Characteristic length
lc = 0.5  # mesh size

# ------------------------------
# I-beam dimensions (mm)
# ------------------------------
H  = 5.0   # total height
B  = 5.0   # flange width
tf = 1.0   # flange thickness
tw = 3.0   # web thickness

# ------------------------------
# Centering at X = 5 (same logic as before)
# ------------------------------
x_center = 5.0

xL = x_center - B / 2
xR = x_center + B / 2
xwL = x_center - tw / 2
xwR = x_center + tw / 2

# ------------------------------
# Define points (counter-clockwise)
# ------------------------------
points = [
    (xL,   0.0),            # 1 bottom flange left
    (xR,   0.0),            # 2 bottom flange right
    (xR,   tf),             # 3
    (xwR,  tf),             # 4
    (xwR,  H - tf),         # 5
    (xR,   H - tf),         # 6
    (xR,   H),              # 7 top flange right
    (xL,   H),              # 8 top flange left
    (xL,   H - tf),         # 9
    (xwL,  H - tf),         #10
    (xwL,  tf),             #11
    (xL,   tf)              #12
]

for i, (x, y) in enumerate(points, start=1):
    gmsh.model.geo.addPoint(x, y, 0.0, lc, i)

# ------------------------------
# Define lines
# ------------------------------
lines = []
for i in range(1, 12):
    lines.append(gmsh.model.geo.addLine(i, i + 1))
lines.append(gmsh.model.geo.addLine(12, 1))  # close loop

# ------------------------------
# Create surface
# ------------------------------
curve_loop = gmsh.model.geo.addCurveLoop(lines)
surface = gmsh.model.geo.addPlaneSurface([curve_loop])

# Synchronize
gmsh.model.geo.synchronize()

# ------------------------------
# Physical group
# ------------------------------
gmsh.model.addPhysicalGroup(2, [surface], 1)
gmsh.model.setPhysicalName(2, 1, "I_Beam")

# ------------------------------
# Mesh settings
# ------------------------------
gmsh.option.setNumber("Mesh.ElementOrder", 1)
gmsh.option.setNumber("Mesh.Algorithm", 6)

gmsh.model.mesh.generate(2)

# Save mesh
gmsh.write("I_beam_5mm.msh")

# Optional visualization
# gmsh.fltk.run()

# Finalize
gmsh.finalize()

# %%
import gmsh
import numpy as np
import matplotlib.pyplot as plt

# ------------------------------
# Initialize Gmsh and load the I-beam mesh
# ------------------------------
gmsh.initialize()
gmsh.open("I_beam_5mm.msh")

# ------------------------------
# Get all nodes
# ------------------------------
node_tags, node_coords, _ = gmsh.model.mesh.getNodes()
node_coords = np.array(node_coords).reshape(-1, 3)

# ------------------------------
# Function to get elements of a physical group
# ------------------------------
def get_elements_of_physical_group(dim, tag):
    entity_tags = gmsh.model.getEntitiesForPhysicalGroup(dim, tag)
    all_elements = []

    for entity_tag in entity_tags:
        element_types, element_tags, node_tags_list = gmsh.model.mesh.getElements(dim, entity_tag)

        for i in range(len(element_types)):
            # Linear triangles → 3 nodes per element
            all_elements.append(
                np.array(node_tags_list[i]).reshape(-1, 3)
            )

    return np.concatenate(all_elements) if all_elements else np.array([])

# ------------------------------
# Get elements for the I-beam (physical group 1)
# ------------------------------
elements_I_beam = get_elements_of_physical_group(2, 1)

# %%
# ------------------------------
# Mesh visualization
# ------------------------------
plt.figure(figsize=(6, 6))

if elements_I_beam.size > 0:
    plt.triplot(
        node_coords[:, 0],        # x-coordinates
        node_coords[:, 1],        # y-coordinates
        elements_I_beam - 1,   # Gmsh is 1-based → Python is 0-based
        linewidth=0.8,
        label="I-beam mesh"
    )

plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("X [mm]")
plt.ylabel("Y [mm]")
plt.title("5 mm × 5 mm I-Beam Mesh")
plt.legend(loc="best")
plt.grid(True, linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Main Functions

# %%
import numpy as np

# ==========================================================
# Jacobian (2 × Area) for a Constant Strain Triangle (CST)
# ==========================================================
def jacobian(coord):
    """
    Compute the absolute value of the Jacobian determinant
    for a 2D linear triangular (CST) element.

    Parameters
    ----------
    coord : ndarray, shape (2, 3)
        Node coordinates of the element:
        coord[0, :] → x-coordinates
        coord[1, :] → y-coordinates

    Returns
    -------
    float
        Absolute value of the Jacobian determinant (2 × element area)
    """
    return abs(
        (coord[0, 0] - coord[0, 2]) * (coord[1, 1] - coord[1, 2]) -
        (coord[0, 1] - coord[0, 2]) * (coord[1, 0] - coord[1, 2])
    )

# %%
# ==========================================================
# Strain–Displacement Matrix (B-matrix) for CST
# ==========================================================
def B_matrix(coord):
    """
    Construct the strain–displacement matrix B for a
    2D Constant Strain Triangle (CST) element.

    Plane strain / plane stress kinematics.

    Parameters
    ----------
    coord : ndarray, shape (2, 3)
        Element node coordinates:
        coord[0, :] → x-coordinates
        coord[1, :] → y-coordinates

    Returns
    -------
    B : ndarray, shape (3, 6)
        Strain–displacement matrix
    """
    x1, x2, x3 = coord[0, :]
    y1, y2, y3 = coord[1, :]

    # Twice the element area (signed)
    A2 = (
        x1 * (y2 - y3) +
        x2 * (y3 - y1) +
        x3 * (y1 - y2)
    )

    # Shape function derivatives (constant over the element)
    dNdx = np.array([
        (y2 - y3) / A2,
        (y3 - y1) / A2,
        (y1 - y2) / A2
    ])

    dNdy = np.array([
        (x3 - x2) / A2,
        (x1 - x3) / A2,
        (x2 - x1) / A2
    ])

    # Assembly of B-matrix
    B = np.zeros((3, 6))
    B[0, 0::2] = dNdx          # ε_xx
    B[1, 1::2] = dNdy          # ε_yy
    B[2, 0::2] = dNdy          # γ_xy
    B[2, 1::2] = dNdx

    return B

# %%
# ==========================================================
# Elastic Constitutive Matrix (Plane Strain)
# ==========================================================
def D_matrix(E, nu):
    """
    Elastic constitutive matrix for isotropic material
    under plane strain conditions.

    Parameters
    ----------
    E : float
        Young's modulus
    nu : float
        Poisson's ratio

    Returns
    -------
    D : ndarray, shape (3, 3)
        Plane strain elasticity matrix
    """
    coef = E / ((1.0 + nu) * (1.0 - 2.0 * nu))

    return coef * np.array([
        [1.0 - nu,     nu,           0.0],
        [nu,           1.0 - nu,     0.0],
        [0.0,          0.0,   0.5 * (1.0 - 2.0 * nu)]
    ])

# %%
# ==========================================================
# Deviatoric Stress (Plane Strain)
# ==========================================================
def deviatoric_part(stress_vector, nu):
    """
    Compute the deviatoric part of the stress tensor
    for plane strain von Mises plasticity.

    Parameters
    ----------
    stress_vector : ndarray, shape (3,)
        [sigma_x, sigma_y, tau_xy]
    nu : float
        Poisson's ratio

    Returns
    -------
    s : ndarray, shape (3,)
        Deviatoric stress vector
    """
    sigma_x, sigma_y, tau_xy = stress_vector

    # Out-of-plane stress (plane strain)
    sigma_z = nu * (sigma_x + sigma_y)

    # Hydrostatic pressure
    p = (sigma_x + sigma_y + sigma_z) / 3.0

    return np.array([
        sigma_x - p,
        sigma_y - p,
        tau_xy
    ])

# %%
# ==========================================================
# Von Mises Equivalent Stress (Plane Strain)
# ==========================================================
def calculate_von_mises_stress(stress_vector, nu):
    """
    Compute von Mises equivalent stress for plane strain.

    Parameters
    ----------
    stress_vector : ndarray, shape (3,)
        [sigma_x, sigma_y, tau_xy]
    nu : float
        Poisson's ratio

    Returns
    -------
    float
        Von Mises equivalent stress
    """
    sigma_x, sigma_y, tau_xy = stress_vector
    sigma_z = nu * (sigma_x + sigma_y)

    return np.sqrt(
        sigma_x**2 + sigma_y**2 + sigma_z**2
        - sigma_x * sigma_y
        - sigma_y * sigma_z
        - sigma_z * sigma_x
        + 3.0 * tau_xy**2
    )

# %%
# ==========================================================
# Yield Function (Isotropic Hardening)
# ==========================================================
def yield_function_plasticity(sigma_eq_tr, kappa, sigma_y0, H):
    """
    Von Mises yield function with isotropic hardening.

    f = sigma_eq - (sigma_y0 + H * kappa)

    Parameters
    ----------
    sigma_eq_tr : float
        Trial equivalent stress
    kappa : float
        Accumulated plastic strain
    sigma_y0 : float
        Initial yield stress
    H : float
        Isotropic hardening modulus

    Returns
    -------
    float
        Value of the yield function
    """
    return sigma_eq_tr - (sigma_y0 + H * kappa)

# %%
# ==========================================================
# Consistent Elastoplastic Tangent (Cep)
# ==========================================================
def compute_Cep(C, stress_vector, H, nu, E):
    """
    Compute the consistent elastoplastic tangent modulus
    for von Mises plasticity with isotropic hardening.

    Parameters
    ----------
    C : ndarray, shape (3, 3)
        Elastic stiffness matrix
    stress_vector : ndarray, shape (3,)
        Current stress state
    H : float
        Isotropic hardening modulus
    nu : float
        Poisson's ratio
    E : float
        Young's modulus

    Returns
    -------
    Cep : ndarray, shape (3, 3)
        Consistent elastoplastic tangent matrix
    """
    # Deviatoric stress
    s = deviatoric_part(stress_vector, nu)

    # Elastic case safeguard
    if np.linalg.norm(s) < 1e-12:
        return C

    # Flow direction
    sigma_eq = calculate_von_mises_stress(stress_vector, nu)
    n_vec = 1.5 * s / sigma_eq
    n = n_vec.reshape(3, 1)

    # Shear modulus
    G = E / (2.0 * (1.0 + nu))

    # Hardening modulus in algorithmic form
    H_star = 3.0 * G + H

    # Consistent tangent operator
    Cep = C - (C @ n @ n.T @ C) / (n.T @ C @ n + H_star)

    return Cep

# %% [markdown]
# # 3. Material properties and Boundary conditions

# %%
# ==========================================================
# FEM MODEL SIZE & SOLVER PARAMETERS
# ==========================================================
num_nodes = node_coords.shape[0]          # Total number of mesh nodes
num_elems = elements_I_beam .shape[0]   # Total number of triangular elements
num_dofs  = 2 * num_nodes                 # 2 DOFs per node (u, v)

max_iter = 300                             # Max Newton–Raphson iterations

# %%
# ==========================================================
# MATERIAL PARAMETERS (Plane Strain, von Mises Plasticity)
# ==========================================================
E         = 30e3       # Young's modulus
nu        = 0.3           # Poisson's ratio
sigma_y0 = 50.0            # Initial yield stress

# Elastic constants
G  = E / (2.0 * (1.0 + nu))               # Shear modulus

# Linear softening law (Et < 0)
Et = -E / 20.0
H  = E * Et / (E - Et)                    # Isotropic hardening modulus

# Elastic stiffness matrix
D_el = D_matrix(E, nu)

# %%
# ==========================================================
# STATE VARIABLES
# ==========================================================

U = np.zeros(num_dofs)                    # Global displacement vector
kappa = np.zeros(num_elems)               # Accumulated plastic strain (per element)

current_stress = np.zeros((num_elems, 3))  # [σx, σy, τxy]
current_strain = np.zeros((num_elems, 3))  # [εx, εy, γxy]

# %%
# ==========================================================
# BOUNDARY CONDITIONS IDENTIFICATION
# ==========================================================
y_coords = node_coords[:, 1]
y_max = y_coords.max()
y_min = y_coords.min()

tol = 1e-8
top_nodes    = np.where(np.isclose(y_coords, y_max, atol=tol))[0]
bottom_nodes = np.where(np.isclose(y_coords, y_min, atol=tol))[0]

# --- DOF numbering ---
# u = 2*i, v = 2*i + 1
disp_dofs = 2 * top_nodes + 1             # Prescribed vertical displacement (top)
bottom_x_dofs = 2 * bottom_nodes           # Fixed u at bottom
bottom_y_dofs = 2 * bottom_nodes + 1       # Fixed v at bottom

fixed_dofs = np.concatenate((bottom_x_dofs, bottom_y_dofs))

free_dofs = np.setdiff1d(
    np.arange(num_dofs),
    np.union1d(fixed_dofs, disp_dofs)
)

# %%
# ==========================================================
# LOAD CONTROL PARAMETERS (DISPLACEMENT CONTROL)
# ==========================================================
u_max = -0.015                             # Maximum imposed displacement
num_steps = 200                            # Load increments

sum_R  = np.zeros(num_steps)               # Reaction force history
sum_du = np.zeros(num_steps)               # Displacement history

# %%
# ==========================================================
# VISUALIZATION OF BCs AND APPLIED DISPLACEMENT
# ==========================================================
plt.figure(figsize=(6, 8))

x = node_coords[:, 0]
y = node_coords[:, 1]
beam_height = y_max - y_min

# --- Mesh outline ---
plt.triplot(
    x, y,
    elements_I_beam  - 1,
    color="lightgray",
    linewidth=0.8,
    label="Mesh"
)

# --- Clamped bottom boundary ---
plt.scatter(
    x[bottom_nodes],
    y[bottom_nodes],
    color="red",
    marker="s",
    s=60,
    label="Clamped boundary ($u = v = 0$)"
)

# --- Top boundary (imposed displacement) ---
plt.scatter(
    x[top_nodes],
    y[top_nodes],
    color="blue",
    marker="o",
    s=50,
    label="Imposed displacement nodes"
)

# --- Displacement arrows ---
arrow_length = 0.15 * beam_height
for n in top_nodes:
    plt.arrow(
        x[n], y[n],
        0.0, arrow_length * np.sign(u_max),
        head_width=0.15,
        head_length=0.25,
        fc="blue",
        ec="blue",
        length_includes_head=True
    )

# --- Text annotations ---
plt.text(
    np.mean(x[top_nodes]),
    y_max - 0.25 * beam_height,
    rf"Imposed displacement" "\n"
    rf"$v = {u_max:.4f}$",
    ha="center",
    va="top",
    fontsize=10,
    color="blue",
    bbox=dict(facecolor="white", edgecolor="blue", alpha=0.8)
)

plt.text(
    np.mean(x[bottom_nodes]),
    y_min + 0.20 * beam_height,
    "Clamped boundary\n$u = v = 0$",
    ha="center",
    va="bottom",
    fontsize=10,
    color="red",
    bbox=dict(facecolor="white", edgecolor="red", alpha=0.8)
)

# --- Plot settings ---
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("X [mm]")
plt.ylabel("Y [mm]")
plt.title("I-Beam – Boundary Conditions and Applied Displacement")
plt.legend(loc="center right")
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Incremental loading--- Newton-Raphson

# %%
# ==========================================================
# MAIN SOLUTION LOOP (Incremental Newton–Raphson)
# ==========================================================
for step in range(num_steps):

    # ------------------------------------------------------
    # Save converged state from previous load step
    # ------------------------------------------------------
    kappa_old  = kappa.copy()
    stress_old = current_stress.copy()
    strain_old = current_strain.copy()

    # Imposed displacement for current load step
    u_step = u_max * (step + 1) / num_steps

    # Enforce Dirichlet boundary conditions
    U[fixed_dofs] = 0.0
    U[disp_dofs]  = u_step

    iter_count = 0

    # ======================================================
    # Newton–Raphson Iterations
    # ======================================================
    while iter_count < max_iter:

        # Global tangent matrix and residual vector
        K = np.zeros((num_dofs, num_dofs))
        R = np.zeros(num_dofs)      # R = -F_int

        # --------------------------------------------------
        # Element loop
        # --------------------------------------------------
        for e in range(num_elems):

            # --- Element connectivity ---
            n1, n2, n3 = (elements_I_beam [e] - 1).astype(int)

            # --- Element coordinates ---
            element_coord = np.array([
                [node_coords[n1, 0], node_coords[n2, 0], node_coords[n3, 0]],
                [node_coords[n1, 1], node_coords[n2, 1], node_coords[n3, 1]]
            ])

            # --- Kinematics ---
            B_e = B_matrix(element_coord)
            A_e = jacobian(element_coord) / 2.0

            edof = np.array([
                2*n1, 2*n1 + 1,
                2*n2, 2*n2 + 1,
                2*n3, 2*n3 + 1
            ])

            # Element displacement vector
            u_e = U[edof]

            # ==================================================
            # 1. ELASTIC PREDICTOR (Trial State)
            # ==================================================
            strain_e = B_e @ u_e
            delta_strain = strain_e - strain_old[e]

            sigma_trial = stress_old[e] + D_el @ delta_strain
            sigma_eq_tr = calculate_von_mises_stress(sigma_trial, nu)

            # Yield function evaluation
            f_trial = yield_function_plasticity(
                sigma_eq_tr, kappa_old[e], sigma_y0, H
            )

            # ==================================================
            # 2. RETURN MAPPING (Plastic Corrector)
            # ==================================================
            if f_trial <= 1e-8:
                # --- Elastic step ---
                sigma_new = sigma_trial
                kappa_new = kappa_old[e]
                Cep = D_el

            else:
                # --- Plastic step ---
                s_tr = deviatoric_part(sigma_trial, nu)
                n_vec = 1.5 * s_tr / sigma_eq_tr

                # Plastic multiplier increment
                dgamma = f_trial / (3.0 * G + H)

                # Stress correction
                sigma_new = sigma_trial - 2.0 * G * dgamma * n_vec

                # Update accumulated plastic strain
                kappa_new = kappa_old[e] + np.sqrt(2.0 / 3.0) * dgamma

                # Consistent elastoplastic tangent
                Cep = compute_Cep(D_el, sigma_new, H, nu, E)

            # --------------------------------------------------
            # Update element history variables
            # --------------------------------------------------
            kappa[e] = kappa_new
            current_stress[e] = sigma_new

            # ==================================================
            # 3. ELEMENT ASSEMBLY
            # ==================================================
            f_int_e = B_e.T @ sigma_new * A_e
            K_e = B_e.T @ Cep @ B_e * A_e

            # Assemble into global residual and tangent
            for i_local in range(6):
                I = edof[i_local]
                R[I] -= f_int_e[i_local]

                for j_local in range(6):
                    J = edof[j_local]
                    K[I, J] += K_e[i_local, j_local]

        # ======================================================
        # 4. SOLVE LINEARIZED SYSTEM
        # ======================================================
        K_ff = K[np.ix_(free_dofs, free_dofs)]
        R_f  = R[free_dofs]

        delta_U = np.zeros_like(U)

        try:
            delta_U[free_dofs] = np.linalg.solve(K_ff, R_f)
        except np.linalg.LinAlgError:
            print("ERROR: Singular tangent matrix. Aborting iteration.")
            break

        # ------------------------------------------------------
        # Update global displacement vector
        # ------------------------------------------------------
        U[free_dofs] += delta_U[free_dofs]

        # Re-apply Dirichlet boundary conditions
        U[fixed_dofs] = 0.0
        U[disp_dofs]  = u_step

        # Convergence check
        res_norm = np.linalg.norm(delta_U[free_dofs])
        if res_norm < 1e-6:
            break

        iter_count += 1

    # ==========================================================
    # POST-CONVERGENCE: REACTIONS & HISTORY UPDATE
    # ==========================================================
    if iter_count < max_iter:

        R_final = np.zeros(num_dofs)

        for e in range(num_elems):

            n1, n2, n3 = (elements_I_beam [e] - 1).astype(int)
            edof = np.array([
                2*n1, 2*n1 + 1,
                2*n2, 2*n2 + 1,
                2*n3, 2*n3 + 1
            ])

            element_coord = np.array([
                [node_coords[n1, 0], node_coords[n2, 0], node_coords[n3, 0]],
                [node_coords[n1, 1], node_coords[n2, 1], node_coords[n3, 1]]
            ])

            B_e = B_matrix(element_coord)
            A_e = jacobian(element_coord) / 2.0

            # Internal force vector
            f_int_e = B_e.T @ current_stress[e] * A_e

            for i_local in range(6):
                R_final[edof[i_local]] -= f_int_e[i_local]

            # Update converged strain
            current_strain[e] = B_e @ U[edof]

        # Resultant reaction force at clamped boundary
        resultant_reaction = np.sum(R_final[bottom_y_dofs])

        # Store load–displacement history
        sum_R[step]  = resultant_reaction
        sum_du[step] = u_step

        print(
            f"Step {step+1:3d} | "
            f"Reaction = {resultant_reaction:10.3f} | "
            f"Max κ = {kappa.max():.6e}"
        )

    else:
        print(
            f"WARNING: Load step {step+1} did not converge "
            f"after {max_iter} iterations. Simulation stopped."
        )
        sum_R = sum_R[:step]
        sum_du = sum_du[:step]
        break
# Out:
# Step   1 | Reaction =     -1.640 | Max κ = 0.000000e+00
# Step   2 | Reaction =     -3.279 | Max κ = 0.000000e+00
# Step   3 | Reaction =     -4.919 | Max κ = 0.000000e+00
# Step   4 | Reaction =     -6.559 | Max κ = 0.000000e+00
# Step   5 | Reaction =     -8.198 | Max κ = 0.000000e+00
# Step   6 | Reaction =     -9.838 | Max κ = 0.000000e+00
# Step   7 | Reaction =    -11.478 | Max κ = 0.000000e+00
# Step   8 | Reaction =    -13.117 | Max κ = 0.000000e+00
# Step   9 | Reaction =    -14.757 | Max κ = 0.000000e+00
# Step  10 | Reaction =    -16.397 | Max κ = 0.000000e+00
# Step  11 | Reaction =    -18.036 | Max κ = 0.000000e+00
# Step  12 | Reaction =    -19.676 | Max κ = 0.000000e+00
# Step  13 | Reaction =    -21.316 | Max κ = 0.000000e+00
# Step  14 | Reaction =    -22.956 | Max κ = 0.000000e+00
# Step  15 | Reaction =    -24.595 | Max κ = 0.000000e+00
# Step  16 | Reaction =    -26.235 | Max κ = 0.000000e+00
# Step  17 | Reaction =    -27.875 | Max κ = 0.000000e+00
# Step  18 | Reaction =    -29.514 | Max κ = 0.000000e+00
# Step  19 | Reaction =    -31.154 | Max κ = 0.000000e+00
# Step  20 | Reaction =    -32.794 | Max κ = 0.000000e+00
# Step  21 | Reaction =    -34.433 | Max κ = 0.000000e+00
# Step  22 | Reaction =    -36.073 | Max κ = 0.000000e+00
# Step  23 | Reaction =    -37.713 | Max κ = 0.000000e+00
# Step  24 | Reaction =    -39.352 | Max κ = 0.000000e+00
# Step  25 | Reaction =    -40.992 | Max κ = 0.000000e+00
# Step  26 | Reaction =    -42.632 | Max κ = 0.000000e+00
# Step  27 | Reaction =    -44.271 | Max κ = 0.000000e+00
# Step  28 | Reaction =    -45.911 | Max κ = 0.000000e+00
# Step  29 | Reaction =    -47.551 | Max κ = 0.000000e+00
# Step  30 | Reaction =    -49.190 | Max κ = 0.000000e+00
# Step  31 | Reaction =    -50.830 | Max κ = 0.000000e+00
# Step  32 | Reaction =    -52.470 | Max κ = 0.000000e+00
# Step  33 | Reaction =    -54.109 | Max κ = 0.000000e+00
# Step  34 | Reaction =    -55.749 | Max κ = 0.000000e+00
# Step  35 | Reaction =    -57.389 | Max κ = 0.000000e+00
# Step  36 | Reaction =    -59.028 | Max κ = 0.000000e+00
# Step  37 | Reaction =    -60.668 | Max κ = 0.000000e+00
# Step  38 | Reaction =    -62.308 | Max κ = 0.000000e+00
# Step  39 | Reaction =    -63.948 | Max κ = 0.000000e+00
# Step  40 | Reaction =    -65.587 | Max κ = 0.000000e+00
# Step  41 | Reaction =    -67.227 | Max κ = 0.000000e+00
# Step  42 | Reaction =    -68.867 | Max κ = 0.000000e+00
# Step  43 | Reaction =    -70.506 | Max κ = 0.000000e+00
# Step  44 | Reaction =    -72.146 | Max κ = 0.000000e+00
# Step  45 | Reaction =    -73.786 | Max κ = 0.000000e+00
# Step  46 | Reaction =    -75.425 | Max κ = 0.000000e+00
# Step  47 | Reaction =    -77.065 | Max κ = 0.000000e+00
# Step  48 | Reaction =    -78.705 | Max κ = 0.000000e+00
# Step  49 | Reaction =    -80.344 | Max κ = 0.000000e+00
# Step  50 | Reaction =    -81.984 | Max κ = 0.000000e+00
# Step  51 | Reaction =    -83.624 | Max κ = 0.000000e+00
# Step  52 | Reaction =    -85.263 | Max κ = 0.000000e+00
# Step  53 | Reaction =    -86.903 | Max κ = 0.000000e+00
# Step  54 | Reaction =    -88.543 | Max κ = 0.000000e+00
# Step  55 | Reaction =    -90.182 | Max κ = 0.000000e+00
# Step  56 | Reaction =    -91.822 | Max κ = 0.000000e+00
# Step  57 | Reaction =    -93.462 | Max κ = 0.000000e+00
# Step  58 | Reaction =    -95.101 | Max κ = 0.000000e+00
# Step  59 | Reaction =    -96.741 | Max κ = 0.000000e+00
# Step  60 | Reaction =    -98.381 | Max κ = 0.000000e+00
# Step  61 | Reaction =   -100.020 | Max κ = 0.000000e+00
# Step  62 | Reaction =   -101.660 | Max κ = 0.000000e+00
# Step  63 | Reaction =   -103.300 | Max κ = 0.000000e+00
# Step  64 | Reaction =   -104.940 | Max κ = 0.000000e+00
# Step  65 | Reaction =   -106.579 | Max κ = 0.000000e+00
# Step  66 | Reaction =   -108.219 | Max κ = 0.000000e+00
# Step  67 | Reaction =   -109.859 | Max κ = 0.000000e+00
# Step  68 | Reaction =   -111.498 | Max κ = 0.000000e+00
# Step  69 | Reaction =   -113.138 | Max κ = 0.000000e+00
# Step  70 | Reaction =   -114.778 | Max κ = 0.000000e+00
# Step  71 | Reaction =   -116.417 | Max κ = 0.000000e+00
# Step  72 | Reaction =   -118.057 | Max κ = 0.000000e+00
# Step  73 | Reaction =   -119.697 | Max κ = 0.000000e+00
# Step  74 | Reaction =   -121.336 | Max κ = 0.000000e+00
# Step  75 | Reaction =   -122.976 | Max κ = 0.000000e+00
# Step  76 | Reaction =   -124.616 | Max κ = 0.000000e+00
# Step  77 | Reaction =   -126.255 | Max κ = 0.000000e+00
# Step  78 | Reaction =   -127.895 | Max κ = 0.000000e+00
# Step  79 | Reaction =   -129.535 | Max κ = 0.000000e+00
# Step  80 | Reaction =   -131.174 | Max κ = 0.000000e+00
# Step  81 | Reaction =   -132.814 | Max κ = 0.000000e+00
# Step  82 | Reaction =   -134.454 | Max κ = 0.000000e+00
# Step  83 | Reaction =   -136.074 | Max κ = 2.254199e-05
# Step  84 | Reaction =   -137.688 | Max κ = 5.065142e-05
# Step  85 | Reaction =   -139.283 | Max κ = 7.987616e-05
# Step  86 | Reaction =   -140.855 | Max κ = 1.081976e-04
# Step  87 | Reaction =   -142.415 | Max κ = 1.364550e-04
# Step  88 | Reaction =   -143.958 | Max κ = 1.639482e-04
# Step  89 | Reaction =   -145.492 | Max κ = 1.907483e-04
# Step  90 | Reaction =   -147.025 | Max κ = 2.174721e-04
# Step  91 | Reaction =   -148.557 | Max κ = 2.441351e-04
# Step  92 | Reaction =   -150.089 | Max κ = 2.709451e-04
# Step  93 | Reaction =   -151.620 | Max κ = 2.977861e-04
# Step  94 | Reaction =   -153.152 | Max κ = 3.245296e-04
# Step  95 | Reaction =   -154.661 | Max κ = 3.577655e-04
# Step  96 | Reaction =   -156.132 | Max κ = 3.930822e-04
# Step  97 | Reaction =   -157.561 | Max κ = 4.283465e-04
# Step  98 | Reaction =   -158.937 | Max κ = 4.648361e-04
# Step  99 | Reaction =   -160.255 | Max κ = 5.002989e-04
# Step 100 | Reaction =   -161.462 | Max κ = 5.372575e-04
# Step 101 | Reaction =   -162.518 | Max κ = 5.792155e-04
# Step 102 | Reaction =   -163.448 | Max κ = 6.253819e-04
# Step 103 | Reaction =   -164.315 | Max κ = 6.750715e-04
# Step 104 | Reaction =   -165.120 | Max κ = 7.306486e-04
# Step 105 | Reaction =   -165.861 | Max κ = 7.869201e-04
# Step 106 | Reaction =   -166.478 | Max κ = 8.443963e-04
# Step 107 | Reaction =   -166.981 | Max κ = 9.030394e-04
# Step 108 | Reaction =   -167.375 | Max κ = 9.640430e-04
# Step 109 | Reaction =   -167.672 | Max κ = 1.024719e-03
# Step 110 | Reaction =   -167.895 | Max κ = 1.084612e-03
# Step 111 | Reaction =   -168.081 | Max κ = 1.142887e-03
# Step 112 | Reaction =   -168.224 | Max κ = 1.199657e-03
# Step 113 | Reaction =   -168.354 | Max κ = 1.256010e-03
# Step 114 | Reaction =   -168.393 | Max κ = 1.311169e-03
# Step 115 | Reaction =   -168.411 | Max κ = 1.367583e-03
# Step 116 | Reaction =   -168.400 | Max κ = 1.427678e-03
# Step 117 | Reaction =   -168.339 | Max κ = 1.493922e-03
# Step 118 | Reaction =   -168.270 | Max κ = 1.561916e-03
# Step 119 | Reaction =   -168.196 | Max κ = 1.636678e-03
# Step 120 | Reaction =   -168.116 | Max κ = 1.737747e-03
# Step 121 | Reaction =   -168.027 | Max κ = 1.838209e-03
# Step 122 | Reaction =   -167.919 | Max κ = 1.936029e-03
# Step 123 | Reaction =   -167.805 | Max κ = 2.033028e-03
# Step 124 | Reaction =   -167.651 | Max κ = 2.133472e-03
# Step 125 | Reaction =   -167.490 | Max κ = 2.235277e-03
# Step 126 | Reaction =   -167.325 | Max κ = 2.337815e-03
# Step 127 | Reaction =   -167.157 | Max κ = 2.440865e-03
# Step 128 | Reaction =   -166.986 | Max κ = 2.544359e-03
# Step 129 | Reaction =   -166.813 | Max κ = 2.648267e-03
# Step 130 | Reaction =   -166.635 | Max κ = 2.753035e-03
# Step 131 | Reaction =   -166.457 | Max κ = 2.857855e-03
# Step 132 | Reaction =   -166.274 | Max κ = 2.962375e-03
# Step 133 | Reaction =   -166.088 | Max κ = 3.066928e-03
# Step 134 | Reaction =   -165.901 | Max κ = 3.171756e-03
# Step 135 | Reaction =   -165.711 | Max κ = 3.276930e-03
# Step 136 | Reaction =   -165.519 | Max κ = 3.382478e-03
# Step 137 | Reaction =   -165.325 | Max κ = 3.488411e-03
# Step 138 | Reaction =   -165.129 | Max κ = 3.594734e-03
# Step 139 | Reaction =   -164.930 | Max κ = 3.701476e-03
# Step 140 | Reaction =   -164.729 | Max κ = 3.808597e-03
# Step 141 | Reaction =   -164.527 | Max κ = 3.916074e-03
# Step 142 | Reaction =   -164.318 | Max κ = 4.023465e-03
# Step 143 | Reaction =   -164.106 | Max κ = 4.130013e-03
# Step 144 | Reaction =   -163.893 | Max κ = 4.236433e-03
# Step 145 | Reaction =   -163.679 | Max κ = 4.342969e-03
# Step 146 | Reaction =   -163.463 | Max κ = 4.449770e-03
# Step 147 | Reaction =   -163.246 | Max κ = 4.556896e-03
# Step 148 | Reaction =   -163.026 | Max κ = 4.664374e-03
# Step 149 | Reaction =   -162.805 | Max κ = 4.772314e-03
# Step 150 | Reaction =   -162.582 | Max κ = 4.880566e-03
# Step 151 | Reaction =   -162.358 | Max κ = 4.989177e-03
# Step 152 | Reaction =   -162.131 | Max κ = 5.098135e-03
# Step 153 | Reaction =   -161.903 | Max κ = 5.207496e-03
# Step 154 | Reaction =   -161.674 | Max κ = 5.317253e-03
# Step 155 | Reaction =   -161.442 | Max κ = 5.427409e-03
# Step 156 | Reaction =   -161.209 | Max κ = 5.537968e-03
# Step 157 | Reaction =   -160.974 | Max κ = 5.648935e-03
# Step 158 | Reaction =   -160.738 | Max κ = 5.760315e-03
# Step 159 | Reaction =   -160.499 | Max κ = 5.872111e-03
# Step 160 | Reaction =   -160.258 | Max κ = 5.984840e-03
# Step 161 | Reaction =   -160.015 | Max κ = 6.097691e-03
# Step 162 | Reaction =   -159.772 | Max κ = 6.210876e-03
# Step 163 | Reaction =   -159.526 | Max κ = 6.324457e-03
# Step 164 | Reaction =   -159.279 | Max κ = 6.438457e-03
# Step 165 | Reaction =   -159.031 | Max κ = 6.552888e-03
# Step 166 | Reaction =   -158.781 | Max κ = 6.667758e-03
# Step 167 | Reaction =   -158.529 | Max κ = 6.783077e-03
# Step 168 | Reaction =   -158.275 | Max κ = 6.898849e-03
# Step 169 | Reaction =   -158.020 | Max κ = 7.015081e-03
# Step 170 | Reaction =   -157.763 | Max κ = 7.131779e-03
# Step 171 | Reaction =   -157.505 | Max κ = 7.248950e-03
# Step 172 | Reaction =   -157.245 | Max κ = 7.366599e-03
# Step 173 | Reaction =   -156.983 | Max κ = 7.484731e-03
# Step 174 | Reaction =   -156.720 | Max κ = 7.603354e-03
# Step 175 | Reaction =   -156.455 | Max κ = 7.722473e-03
# Step 176 | Reaction =   -156.188 | Max κ = 7.842095e-03
# Step 177 | Reaction =   -155.920 | Max κ = 7.962231e-03
# Step 178 | Reaction =   -155.650 | Max κ = 8.082880e-03
# Step 179 | Reaction =   -155.377 | Max κ = 8.204571e-03
# Step 180 | Reaction =   -155.103 | Max κ = 8.326484e-03
# Step 181 | Reaction =   -154.828 | Max κ = 8.448836e-03
# Step 182 | Reaction =   -154.551 | Max κ = 8.571614e-03
# Step 183 | Reaction =   -154.272 | Max κ = 8.694954e-03
# Step 184 | Reaction =   -153.992 | Max κ = 8.818846e-03
# Step 185 | Reaction =   -153.711 | Max κ = 8.943294e-03
# Step 186 | Reaction =   -153.427 | Max κ = 9.068303e-03
# Step 187 | Reaction =   -153.142 | Max κ = 9.193880e-03
# Step 188 | Reaction =   -152.855 | Max κ = 9.320028e-03
# Step 189 | Reaction =   -152.567 | Max κ = 9.446709e-03
# Step 190 | Reaction =   -152.277 | Max κ = 9.574032e-03
# Step 191 | Reaction =   -151.985 | Max κ = 9.701933e-03
# Step 192 | Reaction =   -151.692 | Max κ = 9.830428e-03
# Step 193 | Reaction =   -151.396 | Max κ = 9.959525e-03
# Step 194 | Reaction =   -151.099 | Max κ = 1.008923e-02
# Step 195 | Reaction =   -150.801 | Max κ = 1.021955e-02
# Step 196 | Reaction =   -150.500 | Max κ = 1.035045e-02
# Step 197 | Reaction =   -150.198 | Max κ = 1.048192e-02
# Step 198 | Reaction =   -149.893 | Max κ = 1.061397e-02
# Step 199 | Reaction =   -149.587 | Max κ = 1.074657e-02
# Step 200 | Reaction =   -149.280 | Max κ = 1.087975e-02

# %%
# ==========================================================
# FORCE–DISPLACEMENT CURVE
# ==========================================================
plt.figure(figsize=(8, 6))

# Plot absolute values (compression / tension symmetry)
plt.plot(
    np.abs(sum_du),
    np.abs(sum_R),
    linewidth=2.0,
    color="darkred",
    label="Force–displacement response"
)

# Labels and title
plt.xlabel(r"Imposed displacement $|u|$ [m]")
plt.ylabel(r"Resultant vertical reaction $|R|$ [N]")
plt.title(
    rf"Force–Displacement Curve "
    rf"($E={E:.0f}$, $E_t={Et:.0f}$, linear softening)"
)

# Formatting
plt.grid(True, linestyle="--", alpha=0.7)
plt.legend(loc="best")
plt.tight_layout()

plt.show()

# %% [markdown]
# # 5. Saving Data

# %%
# ==========================================================
# FINAL POST-PROCESSING AND DATA EXPORT
# ==========================================================
import pandas as pd

# ---------- LOAD–DISPLACEMENT HISTORY ----------
df_load_disp = pd.DataFrame({
    "imposed_displacement [m]": sum_du,
    "resultant_reaction [N]": sum_R
})

filename = f"Finally_Softened_lc_{lc}.xlsx"

with pd.ExcelWriter(filename, engine="openpyxl") as writer:
    df_load_disp.to_excel(writer, sheet_name="Load_Displacement", index=False)
print(f"\n✔ Results successfully saved to '{filename}'")
# Out:
# ✔ Results successfully saved to 'Finally_Softened_lc_0.5.xlsx'

# %% [markdown]
# # 6. Plottings

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.tri as tri

# ==========================================================
# COMMON PREPARATIONS
# ==========================================================
scale_factor = 25
dofs_per_node = 2

# --- Deformed coordinates ---
U_nodes = U.reshape(num_nodes, dofs_per_node)
deformed_node_coords = node_coords.copy()
deformed_node_coords[:, 0] += U_nodes[:, 0] * scale_factor
deformed_node_coords[:, 1] += U_nodes[:, 1] * scale_factor

# --- Triangulation (zero-based indexing) ---
triang = tri.Triangulation(
    node_coords[:, 0],
    node_coords[:, 1],
    elements_I_beam  - 1
)

# --- Element-wise displacement magnitude ---
nodal_disp_mag = np.linalg.norm(U_nodes, axis=1)
element_disp_mag = np.zeros(num_elems)
for e in range(num_elems):
    node_ids = (elements_I_beam [e] - 1).astype(int)
    element_disp_mag[e] = np.mean(nodal_disp_mag[node_ids])

# --- Element-wise Von Mises stress ---
von_mises = np.zeros(num_elems)
for e in range(num_elems):
    von_mises[e] = calculate_von_mises_stress(current_stress[e], nu)

# --- Stress components (σ_xx, σ_yy, σ_xy) ---
sigma_xx = np.array([current_stress[e, 0] for e in range(num_elems)])
sigma_yy = np.array([current_stress[e, 1] for e in range(num_elems)])
sigma_xy = np.array([current_stress[e, 2] for e in range(num_elems)])

# %%
# ==========================================================
# 1) DEFORMED SHAPE
# ==========================================================
plt.figure(figsize=(10, 6))
plt.triplot(node_coords[:, 0], node_coords[:, 1], elements_I_beam  - 1,
            color="gray", linewidth=0.6, label="Original mesh")
plt.triplot(deformed_node_coords[:, 0], deformed_node_coords[:, 1], elements_I_beam  - 1,
            color="red", linewidth=1.0, label=f"Deformed mesh (×{scale_factor})")
plt.gca().set_aspect("equal")
plt.title("Deformed I-Beam Shape")
plt.xlabel("X [mm]")
plt.ylabel("Y [mm]")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %%
# ==========================================================
# 2) STRESS FIELDS (σ_xx, σ_yy, σ_xy) SIDE BY SIDE
# ==========================================================
fig, axs = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

stress_fields = [sigma_xx, sigma_yy, sigma_xy]
titles = [r"$\sigma_{xx}$", r"$\sigma_{yy}$", r"$\sigma_{xy}$"]

for i in range(3):
    pc = axs[i].tripcolor(triang, facecolors=stress_fields[i], edgecolors="k", cmap="jet")
    fig.colorbar(pc, ax=axs[i], label="Stress [MPa]")
    axs[i].set_aspect("equal")
    axs[i].set_title(titles[i])
    axs[i].set_xlabel("X [mm]")
    axs[i].set_ylabel("Y [mm]")
    axs[i].grid(True, linestyle="--", alpha=0.6)

plt.show()

# %%
# ==========================================================
# 3) VON MISES STRESS
# ==========================================================
plt.figure(figsize=(10, 6))
vm_plot = plt.tripcolor(triang, facecolors=von_mises, edgecolors="k", cmap="jet")
plt.colorbar(vm_plot, label="Von Mises stress [MPa]")
plt.gca().set_aspect("equal")
plt.title("Equivalent Von Mises Stress")
plt.xlabel("X [mm]")
plt.ylabel("Y [mm]")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %%
# ==========================================================
# 4) DISPLACEMENT MAGNITUDE
# ==========================================================
plt.figure(figsize=(10, 6))
disp_plot = plt.tripcolor(triang, facecolors=element_disp_mag, edgecolors="k", cmap="jet")
plt.colorbar(disp_plot, label="Displacement magnitude [mm]")
plt.gca().set_aspect("equal")
plt.title("Element-wise Displacement Magnitude")
plt.xlabel("X [mm]")
plt.ylabel("Y [mm]")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
